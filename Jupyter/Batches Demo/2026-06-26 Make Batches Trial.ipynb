# %% [markdown]
# # Making Batches of Data to a Folder
#
# Note that this will save data both into our lab-wide Tiled server and into our local folder
#
# You'll need to have TILED_API_KEY and TILED_URI environment variables set.

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Global Imports

# %%
import numpy as np

from bluesky import RunEngine
from bluesky.callbacks import LiveTable
from bluesky.plans import count, list_scan
import bluesky.plan_stubs as bps

from bluesky.callbacks.tiled_writer import TiledWriter
from tiled.server import SimpleTiledServer
from tiled.client import from_uri

from ophyd_async.core import init_devices

import matplotlib.pyplot as plt

# %% [markdown]
# ### Local-File Imports

# %%
from sidekick_model3_CA_devices import PulseGenerator, LilLaser, Diode
from sidekick_model3_PVA_devices_v3 import DiodePVA
from array_steps import array_one_nd_step_with_reps
from sidekick_model3_helpers import condition_pulse

# %% [markdown]
# ## Initialize our Sidekick Model 3 Devices

# %% [markdown]
# ### Simple Device Interfaces (Channel Access, ophyd)

# %%
pulsegen = PulseGenerator('PULSEGEN:', name='pulsegen')
laser = LilLaser('LASER:', name='laser')
electron = Diode('ELECTRON:', name='electron')
proton = Diode('PROTON:', name='proton')

for device in [pulsegen, laser, electron, proton]:
    device.wait_for_connection()

# %% [markdown]
# ### High-Performance Device Interfaces (PVAccess, ophyd-async)

# %% [markdown]
# #### Start Bluesky RunEngine (before initializing ophyd-async devices)

# %%
RE = RunEngine()

# %% [markdown]
# #### Initialize ophyd-async devices

# %%
with init_devices():
    electron_pva = DiodePVA(prefix="pva://ELECTRON-DAQ:", name="electron_pva")
    proton_pva = DiodePVA(prefix="pva://PROTON-DAQ:", name="proton_pva")

# %% [markdown]
# ## Connect to our Lab-Wide Tiled Server, and Subscribe to Run Engine

# %%
import os
from tiled.client import from_uri

def get_tiled_client():
    """Connect to Tiled using environment variables.
    Simple helper function written by ChatGPT"""

    tiled_uri = os.environ.get("TILED_URI")
    tiled_api_key = os.environ.get("TILED_API_KEY")

    if tiled_uri is None:
        raise RuntimeError(
            "Missing TILED_URI.\n"
            "Example:\n"
            "    export TILED_URI='http://your-tiled-server.lan:8000'\n"
        )

    if tiled_api_key is None:
        raise RuntimeError(
            "Missing TILED_API_KEY.\n"
            "Example:\n"
            "    export TILED_API_KEY='your-api-key-here'\n"
        )

    return from_uri(tiled_uri, api_key=tiled_api_key)

# %%
tiled_client = get_tiled_client()

# %%
tw = TiledWriter(tiled_client)
RE.subscribe(tw)
# Out:
# 0

# %% [markdown]
# ## Create and Execute Plan to Put Sidekick in a Known Initial State

# %% [markdown]
# ### Create Plan to Set timing settings and rep-rate.

# %%
# Written by ChatGPT with help from Scott Feister on 2026-06-22.
# Simple Bluesky pre-run setup helper for putting Sidekick devices
# into a known initial state before opening a run.

def prepare_for_run():
    """Put the Sidekick Model 3 into the standard initial state before a run.
    """

    # Set all delta-t values.
    yield from bps.mv(
        proton.dt, 5.0e-6,        # seconds
        electron.dt, 5.0e-6,      # seconds
        laser.powers_dt, 5.0,     # microseconds
    )

    # Set trigger delays to known values.
    yield from bps.mv(
        pulsegen.ch2_delay, 100.0,    # microseconds; proton delay
        pulsegen.ch3_delay, 100.0,    # microseconds; electron delay
        pulsegen.ch4_delay, 100.0,    # microseconds; laser delay
    )

    # Set system repetition rate.
    yield from bps.mv(
        pulsegen.reprate, 50.0,       # Hz
    )

# %% [markdown]
# ### Execute this Plan

# %%
RE(prepare_for_run())
# Out:
# ()

# %% [markdown]
# ## One-off Test: 200 random traces with 3 reps on each?
# Empirically, it takes about 130 ms per laser setting (one rep) or 140 ms per laser setting (two reps) or 195 ms per laser setting (three reps) or 760 ms per laser (twenty reps) or 1400 ms per laser setting (40 reps). So like 35 ms per rep, and 100 ms per laser setting. Rep rate is 50 Hz, or 20 ms per trace at best.
#
# Anyway, empirically 200 random traces with 3 reps each takes about 40 seconds. This makes it a decent batch size; long enough to make the Tiled connection overhead insignificant, short enough to feel "real-time".

# %%
npulses = 200
reps = 3

pulse_list = [condition_pulse(np.round(np.random.rand(100)*255)) for i in range(npulses)]
pulse_list[0].shape
# Out:
# (100,)

# %%
# %%time

detectors = [electron_pva.trace, proton_pva.trace]
motor = laser.powers
motor_points = pulse_list
md = {"user_note" : "A bunch of random traces, list scan on Sidekick Model 3"}
uid, = RE(list_scan(detectors, motor, motor_points, md=md, per_step=array_one_nd_step_with_reps(reps=reps)))
# Out:
# CPU times: total: 8.48 s
# Wall time: 38.8 s

# %% [markdown]
# ### Export data

# %%
"""
Export one specific kind of run to from Tiled to HDF5.

Created by ChatGPT with help from Scott Feister on 2026-06-25.
"""

from pathlib import Path

import h5py
import numpy as np


def export_run_to_hdf5_custom2(tiled_client, uid, filename=None):
    if filename is None:
        filename = f"run_{uid}.h5"

    filename = Path(filename)
    filename.parent.mkdir(parents=True, exist_ok=True)

    primary = tiled_client[uid, "primary"]

    with h5py.File(filename, "w") as f:
        f.attrs["uid"] = uid

        g = f.create_group("primary")

        g.create_dataset("scan_step", data=np.asarray(primary["scan_step"]))
        g.create_dataset("scan_rep", data=np.asarray(primary["scan_rep"]))
        g.create_dataset("laser_powers", data=np.asarray(primary["laser_powers"]))
        g.create_dataset("electron_trace", data=np.asarray(primary["electron_pva-trace-array"]))
        g.create_dataset("electron_shot_num", data=np.asarray(primary["electron_pva-trace-uniqueId"]))
        g.create_dataset("proton_trace", data=np.asarray(primary["proton_pva-trace-array"]))
        g.create_dataset("proton_shot_num", data=np.asarray(primary["proton_pva-trace-uniqueId"]))

    return filename

# %%
export_run_to_hdf5_custom2(tiled_client, uid, f"outputs/run_{uid}.h5")
# Out:
# WindowsPath('outputs/run_4ffe42ca-0376-48c1-b316-0df0fcecbae8.h5')

# %%
#!/usr/bin/env python3
"""
export_batch_hdf5.py

Export one Tiled run to the next numbered HDF5 batch file.

Each exported run becomes one file:

    outputs/batches/batch_001.h5
    outputs/batches/batch_002.h5
    ...

Written by ChatGPT with help from Scott Feister on 2026-06-26.
"""

from pathlib import Path
import re


# -----------------------
# Settings
# -----------------------

outputs_dir = Path("outputs")
batches_dir = outputs_dir / "batches"


# -----------------------
# Helper: find next batch number
# -----------------------

def get_existing_batch_numbers():
    batch_numbers = []

    for path in batches_dir.glob("batch_*"):
        # Accept both old-style folders:
        #     batch_001/
        #
        # and new-style HDF5 files:
        #     batch_001.h5
        match = re.fullmatch(r"batch_(\d+)(?:\.h5)?", path.name)

        if match:
            batch_numbers.append(int(match.group(1)))

    return sorted(batch_numbers)


def get_next_batch_number():
    existing_numbers = get_existing_batch_numbers()

    if not existing_numbers:
        return 1

    return max(existing_numbers) + 1


def get_next_batch_hdf5_path():
    batches_dir.mkdir(parents=True, exist_ok=True)

    batch_number = get_next_batch_number()
    batch_name = f"batch_{batch_number:03d}.h5"

    return batches_dir / batch_name


# -----------------------
# Export one run
# -----------------------

def export_run_as_next_batch(tiled_client, uid):
    batch_path = get_next_batch_hdf5_path()

    export_run_to_hdf5_custom2(
        tiled_client,
        uid,
        batch_path,
    )

    print(f"Wrote {batch_path}")

    return batch_path

# %%
export_run_as_next_batch(tiled_client, uid)
# Out:
# Wrote outputs\batches\batch_002.h5
# WindowsPath('outputs/batches/batch_002.h5')

# %% [markdown]
# ## Run and Save - in a Loop
#
# Note that this has failed before because of a single rogue waveform from laser_powers coming into Tiled as 9 elements long.

# %%
detectors = [electron_pva.trace, proton_pva.trace]
motor = laser.powers

for i in range(20):
    pulse_list = [condition_pulse(np.round(np.random.rand(100)*255)) for i in range(npulses)]
    motor_points = pulse_list
    md = {"user_note" : "Acquire and save in a loop, repeated list scans on Sidekick Model 3", "outer_loop_i": i}
    uid, = RE(list_scan(detectors, motor, motor_points, md=md, per_step=array_one_nd_step_with_reps(reps=reps)))
    export_run_as_next_batch(tiled_client, uid)
# Out:
# Wrote outputs\batches\batch_006.h5
# Wrote outputs\batches\batch_007.h5
# Wrote outputs\batches\batch_008.h5
# Wrote outputs\batches\batch_009.h5
# Wrote outputs\batches\batch_010.h5
# Wrote outputs\batches\batch_011.h5
# Wrote outputs\batches\batch_012.h5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 9
#       5     pulse_list = [condition_pulse(np.round(np.random.rand(100)*255)) for i in range(npulses)]
#       6     motor_points = pulse_list
#       7     md = {"user_note" : "Acquire and save in a loop, repeated list scans on Sidekick Model 3", "outer_loop_i": i}
#       8     uid, = RE(list_scan(detectors, motor, motor_points, md=md, per_step=array_one_nd_step_with_reps(reps=reps)))
# ----> 9     export_run_as_next_batch(tiled_client, uid)
#
# Cell In[41], line 74, in export_run_as_next_batch(tiled_client, uid)
#      71 def export_run_as_next_batch(tiled_client, uid):
#      72     batch_path = get_next_batch_hdf5_path()
#      73
# ---> 74     export_run_to_hdf5_custom2(
#      75         tiled_client,
#      76         uid,
#      77         batch_path,
#
# Cell In[39], line 29, in export_run_to_hdf5_custom2(tiled_client, uid, filename)
#      25         g = f.create_group("primary")
#      26
#      27         g.create_dataset("scan_step", data=np.asarray(primary["scan_step"]))
#      28         g.create_dataset("scan_rep", data=np.asarray(primary["scan_rep"]))
# ---> 29         g.create_dataset("laser_powers", data=np.asarray(primary["laser_powers"]))
#      30         g.create_dataset("electron_trace", data=np.asarray(primary["electron_pva-trace-array"]))
#      31         g.create_dataset("electron_shot_num", data=np.asarray(primary["electron_pva-trace-uniqueId"]))
#      32         g.create_dataset("proton_trace", data=np.asarray(primary["proton_pva-trace-array"]))
#
# File ~\miniforge3\envs\epics\Lib\site-packages\h5py\_hl\group.py:240, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     237         parent_path, name = name.rsplit(b'/', 1)
#     238         group = self.require_group(parent_path)
# --> 240 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     241 dset = dataset.Dataset(dsid)
#     242 return dset
#
# File ~\miniforge3\envs\epics\Lib\site-packages\h5py\_hl\dataset.py:102, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0, fill_time)
#     100     else:
#     101         dtype = numpy.dtype(dtype)
# --> 102     tid = h5t.py_create(dtype, logical=1)
#     104 # Legacy
#     105 if any((compression, shuffle, fletcher32, maxshape, scaleoffset)) and chunks is False:
#
# File h5py/h5t.pyx:1745, in h5py.h5t.py_create()
# -> 1745 'Could not get source, probably due dynamically evaluated source code.'
#
# File h5py/h5t.pyx:1769, in h5py.h5t.py_create()
# -> 1769 'Could not get source, probably due dynamically evaluated source code.'
#
# File h5py/h5t.pyx:1836, in h5py.h5t.py_create()
# -> 1836 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: Object dtype dtype('O') has no native HDF5 equivalent

# %%
primary = tiled_client[uid]["primary"]

# %%
primary
# Out:
# <BlueskyEventStream {'scan_step', 'electron_pva-trace-timeStamp', 'electron_pva-trace-array', 'laser_powers', 'time', 'proton_pva-trace-timeStamp', 'scan_rep', 'electron_pva-trace-uniqueId', 'proton_pva-trace-array', 'proton_pva-trace-uniqueId'} stream_name='primary'>

# %%
primary["laser_powers"]
# Out:
# <RaggedClient shape=(600, None) size=59950 chunks=((600,), None) dtype=int64>

# %%
laser_powers = primary["laser_powers"].read()

bad = []

for i, x in enumerate(laser_powers):
    arr = np.asarray(x)
    if len(arr) != 100:
        bad.append((i, len(arr)))

print(bad[:50])
print(f"Number of bad rows: {len(bad)}")


lengths = [len(np.asarray(x)) for x in laser_powers]

print(len(lengths))
print(min(lengths))
print(max(lengths))
print(sorted(set(lengths))[:20])
print(sum(lengths))
# Out:
# [(1, 50)]
# Number of bad rows: 1
# 600
# 50
# 100
# [50, 100]
# 59950

# %%
for i, x in enumerate(laser_powers):
    arr = np.asarray(x)
    if len(arr) != 100:
        print(i, arr.shape, arr)
# Out:
# 1 (50,) [ragged.array(97) ragged.array(161) ragged.array(49) ragged.array(187)
#  ragged.array(250) ragged.array(51) ragged.array(247) ragged.array(166)
#  ragged.array(49) ragged.array(218) ragged.array(80) ragged.array(138)
#  ragged.array(100) ragged.array(80) ragged.array(241) ragged.array(74)
#  ragged.array(162) ragged.array(186) ragged.array(212) ragged.array(246)
#  ragged.array(47) ragged.array(1) ragged.array(225) ragged.array(11)
#  ragged.array(140) ragged.array(125) ragged.array(42) ragged.array(185)
#  ragged.array(39) ragged.array(141) ragged.array(34) ragged.array(59)
#  ragged.array(98) ragged.array(49) ragged.array(213) ragged.array(156)
#  ragged.array(84) ragged.array(228) ragged.array(164) ragged.array(59)
#  ragged.array(118) ragged.array(171) ragged.array(2) ragged.array(140)
#  ragged.array(91) ragged.array(246) ragged.array(120) ragged.array(130)
#  ragged.array(37) ragged.array(110)]

# %%
bad_i = 1  # replace this with the bad index

print("scan_step:", np.asarray(primary["scan_step"])[bad_i])
print("scan_rep:", np.asarray(primary["scan_rep"])[bad_i])

print("laser powers shape:", np.asarray(primary["laser_powers"][bad_i]).shape)

print("electron trace shape:", np.asarray(primary["electron_pva-trace-array"][bad_i]).shape)
print("proton trace shape:", np.asarray(primary["proton_pva-trace-array"][bad_i]).shape)

print("electron shot:", np.asarray(primary["electron_pva-trace-uniqueId"])[bad_i])
print("proton shot:", np.asarray(primary["proton_pva-trace-uniqueId"])[bad_i])
# Out:
# scan_step: 0
# scan_rep: 1
# laser powers shape: (50,)
# electron trace shape: (100,)
# proton trace shape: (100,)
# electron shot: 13378531
# proton shot: 13378530

# %%
uid
# Out:
# '007d34f3-9a1a-4aa7-b57f-9b3f099fe73d'
