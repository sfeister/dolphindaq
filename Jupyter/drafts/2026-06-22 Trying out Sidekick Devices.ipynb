# %% [markdown]
# # Trying out Sidekick Devices
#
# Loading them in and using them

# %%
from sidekick_model3_CA_devices import PulseGenerator, LilLaser, Diode

# %%
pulsegen = PulseGenerator('PULSEGEN:', name='pulsegen')
pulsegen.wait_for_connection()
pulsegen
# Out:
# PulseGenerator(prefix='PULSEGEN:', name='pulsegen', read_attrs=['info', 'debug', 'trigger_count', 'output_enabled', 'reprate', 'ch1_delay', 'ch2_delay', 'ch3_delay', 'ch4_delay'], configuration_attrs=[])

# %%
laser = LilLaser('LASER:', name='laser')
laser.wait_for_connection()
laser
# Out:
# LilLaser(prefix='LASER:', name='laser', read_attrs=['info', 'debug', 'trigger_count', 'output_enabled', 'powers_nt', 'powers_dt', 'powers'], configuration_attrs=[])

# %%
electron = Diode('ELECTRON:', name='electron')
electron.wait_for_connection()
electron
# Out:
# Diode(prefix='ELECTRON:', name='electron', read_attrs=['info', 'debug', 'trigger_count', 'dt', 'trace_dt', 'trace_nt', 'trace_ymin', 'trace_ymax', 'trace_yarr'], configuration_attrs=[])

# %%
proton = Diode('PROTON:', name='proton')
proton.wait_for_connection()
proton
# Out:
# Diode(prefix='PROTON:', name='proton', read_attrs=['info', 'debug', 'trigger_count', 'dt', 'trace_dt', 'trace_nt', 'trace_ymin', 'trace_ymax', 'trace_yarr'], configuration_attrs=[])
