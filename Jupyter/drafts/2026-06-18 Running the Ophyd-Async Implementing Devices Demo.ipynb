# %% [markdown]
# # Following official documentation on implementing devices
#
# Trying to follow along with the official ophyd-async tutorial

# %% [markdown]
# ## References:
# 1. [Ophyd-Async Tutorial: Implementing Devices](https://blueskyproject.io/ophyd-async/main/tutorials/implementing-devices.html)

# %% [markdown]
# ## Run the Demo

# %%
# %run -m ophyd_async.epics.demo

# %%
RE(bp.grid_scan([pdet], stage.x, 1, 2, 3, stage.y, 2, 3, 3))
# Out:
# Transient Scan ID: 1     Time: 2026-06-18 14:26:02
# Persistent Unique Scan ID: '63c5f1d0-10a4-47bd-bb4c-0424e9043033'
# New stream: 'primary'
# +-----------+------------+------------+------------+----------------------+----------------------+----------------------+
# |   seq_num |       time |    stage-x |    stage-y | pdet-channel-1-value | pdet-channel-2-value | pdet-channel-3-value |
# +-----------+------------+------------+------------+----------------------+----------------------+----------------------+
# |         1 | 14:26:04.3 |      1.000 |      2.000 |                  921 |                  887 |                  859 |
# |         2 | 14:26:05.8 |      1.000 |      2.500 |                  959 |                  926 |                  898 |
# |         3 | 14:26:07.3 |      1.000 |      3.000 |                  937 |                  903 |                  875 |
# ...

# %% [markdown]
# ## See how devices are Instantiated
